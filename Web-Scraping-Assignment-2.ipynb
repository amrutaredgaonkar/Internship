# %% [markdown]
# #Q1.Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location.
# You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10
# jobs data.

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\hp\anaconda3\lib\site-packages (4.17.2)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (1.26.16)
# Requirement already satisfied: trio~=0.17 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (0.24.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (2023.5.7)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (4.9.0)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\hp\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\hp\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\hp\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\hp\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
options = Options()
options.headless = True

# %%
webdriver_path = "path/to/chromedriver.exe"

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.shine.com/')

# %%
designation = driver.find_element(By.CLASS_NAME,"form-control")
designation.send_keys('Data Analyst')

# %%
location = driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/div/div[2]/div[2]/div[1]/form/div/div[1]/ul/li[2]/div/input")
location.send_keys("Bangalore")

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/div/div[2]/div[2]/div[1]/form/div/div[2]/div/button")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags = driver.find_elements(By.XPATH, '//h2[@itemprop="name"]')
for i in title_tags[0:10]:
    title = i.text
    job_title.append(title)

location_tags = driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags[0:10]:
    location = i.text
    job_location.append(location)

company_tags = driver.find_elements(By.XPATH, '//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags[0:10]:
    company = i.text
    company_name.append(company)

exp_tags = driver.find_elements(By.XPATH, '//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in exp_tags[0:10]:
    exp = i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({'TITLE':job_title,'LOCATION':job_location,'COMPANY NAME':company_name,'EXPERIENCE REQUIRED':experience_required})
df
# Out:
#                                                TITLE        LOCATION  \
# 0                                  Lead Data Analyst       Bangalore
# 1                                       Data Analyst   Bangalore\n+3
# 2                           Vacancy For Data Analyst  Bangalore\n+14
# 3                              Clinical Data Analyst   Bangalore\n+6
# 4                                    Data Management  Bangalore\n+18
# 5                                  Data Modeler data       Bangalore
# 6                                      Data Modeller       Bangalore
# 7                             Data Modeler Bangalore       Bangalore
# 8                                       Data Modeler       Bangalore
# 9  Full time Opportunity-Networking Advisor-Cisco...   Bangalore\n+5
#
#                              COMPANY NAME EXPERIENCE REQUIRED
# 0           ara resources private limited          4 to 9 Yrs
# 1       diraa hr services hiring for mncs           0 to 1 Yr
# 2                yogita staffing solution          0 to 3 Yrs
# 3                           techno endura           0 to 1 Yr
# 4                  future solution centre       15 to >25 Yrs
# 5  boyen haddin consulting and technol...          3 to 6 Yrs
# 6  boyen haddin consulting and technol...          3 to 6 Yrs
# 7  boyen haddin consulting and technol...          3 to 6 Yrs
# 8  boyen haddin consulting and technol...          3 to 6 Yrs
# 9  ntt data information processing ser...        10 to 20 Yrs

# %% [markdown]
# #Q2 Write a python program to scrape data for “Data Scientist” Job position in“Bangalore” location. You
# have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
options = Options()
options.headless = True

# %%
webdriver_path = "path/to/chromedriver.exe"

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.shine.com/')

# %%
designation = driver.find_element(By.CLASS_NAME,"form-control")
designation.send_keys('Data Scientist')

# %%
location = driver.find_element(By.XPATH,"/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input")
location.send_keys("Bangalore")

# %%
search=driver.find_element(By.XPATH,"/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[2]/div/button")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]

# %%
title_tags = driver.find_elements(By.XPATH, '//h2[@itemprop="name"]')
for i in title_tags[0:10]:
    title = i.text
    job_title.append(title)

location_tags = driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags[0:10]:
    location = i.text
    job_location.append(location)

company_tags = driver.find_elements(By.XPATH, '//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags[0:10]:
    company = i.text
    company_name.append(company)

# %%
df=pd.DataFrame({'TITLE':job_title,'LOCATION':job_location,'COMPANY NAME':company_name,'EXPERIENCE REQUIRED':experience_required})
df
# Out:
#                                                TITLE        LOCATION  \
# 0                                  ML Data Scientist   Bangalore\n+3
# 1                      Data Scientist Urgent Vacancy  Bangalore\n+15
# 2                         Data Scientist Recruitment  Bangalore\n+15
# 3                         Data Scientist Recruitment  Bangalore\n+15
# 4                                     Data Scientist   Bangalore\n+4
# 5                                     Data Scientist       Bangalore
# 6      Lead Data Scientist/ Principal Data Scientist   Bangalore\n+1
# 7  Vacancy For Data Scientist Fresher and Experience  Bangalore\n+14
# 8                              Senior Data Scientist   Bangalore\n+1
# 9                                Lead Data Scientist   Bangalore\n+1
#
#                              COMPANY NAME EXPERIENCE REQUIRED
# 0  gujarat facility services hiring fo...          4 to 9 Yrs
# 1                      renuka interprises           0 to 1 Yr
# 2                      renuka interprises          0 to 3 Yrs
# 3                      renuka interprises           0 to 1 Yr
# 4           acme services private limited       15 to >25 Yrs
# 5                     ltimindtree limited          3 to 6 Yrs
# 6                                 fractal          3 to 6 Yrs
# 7                yogita staffing solution          3 to 6 Yrs
# 8                                neostats          3 to 6 Yrs
# 9                                   aereo        10 to 20 Yrs

# %% [markdown]
# #Q3: In this question you have to scrape data using the filters available on the webpage
#  You have to use the location and salary filter.
# You have to scrape data for “Data Scientist” designation for first 10 job results.
# You have to scrape the job-title, job-location, company name, experience required.
# The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs

# %%
driver=webdriver.Chrome()
driver.get('https://www.shine.com/')

# %%
designation = driver.find_element(By.CLASS_NAME,"form-control")
designation.send_keys('Data Scientist')

# %%
search=driver.find_element(By.XPATH,"/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[2]/div/button")
search.click()

# %%
location = driver.find_element(By.XPATH,"/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input")
location.send_keys("Delhi/NCR")

# %%
salary = driver.find_element(By.XPATH,"/html/body/div[3]/div/div/div/div[3]/div/div/div/ul/li[1]/input")
salary.send_keys("3 To 5 Lakh")

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags = driver.find_elements(By.XPATH, '//h2[@itemprop="name"]')
for i in title_tags[0:10]:
    title = i.text
    job_title.append(title)

location_tags = driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags[0:10]:
    location = i.text
    job_location.append(location)

company_tags = driver.find_elements(By.XPATH, '//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags[0:10]:
    company = i.text
    company_name.append(company)

exp_tags = driver.find_elements(By.XPATH, '//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in exp_tags[0:10]:
    exp = i.text
    experience_required.append(exp)

# %%
df=pd.DataFrame({'TITLE':job_title,'LOCATION':job_location,'COMPANY NAME':company_name,'EXPERIENCE REQUIRED':experience_required})
df
# Out:
#                                                TITLE         LOCATION  \
# 0                                     Data Scientist     Gurugram\n+4
# 1  Vacancy For Data Scientist Fresher and Experience      Canada\n+14
# 2  Vacancy For Data Scientist Fresher and Experience      Canada\n+14
# 3  Vacancy For Data Scientist Fresher and Experience      Canada\n+14
# 4                      Data Scientist Urgent Vacancy      Canada\n+14
# 5                      Data Scientist Urgent Vacancy      Canada\n+14
# 6                      Data Scientist Urgent Vacancy      Canada\n+14
# 7                             Data Scientist (ML/AI)             Pune
# 8                                     Data Scientist    Bangalore\n+2
# 9                              Pharma Data Scientist  Mumbai City\n+4
#
#                       COMPANY NAME EXPERIENCE REQUIRED
# 0    acme services private limited          3 to 5 Yrs
# 1         yogita staffing solution          0 to 3 Yrs
# 2         yogita staffing solution          0 to 3 Yrs
# 3         yogita staffing solution          0 to 3 Yrs
# 4         yogita staffing solution          0 to 3 Yrs
# 5         yogita staffing solution          0 to 3 Yrs
# 6         yogita staffing solution          0 to 3 Yrs
# 7  gfl recruitment private limited           0 to 1 Yr
# 8                diraa hr services          0 to 4 Yrs
# 9                  quiscon biotech           0 to 1 Yr

# %% [markdown]
# #Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 6. Brand
# 7. ProductDescription
# 8. Price
# The attributes which you have to scrape is ticked marked in the below image.

# %%
driver = webdriver.Chrome()
driver.get("https://www.flipkart.com/")

# %%
sr=driver.find_element(By.CLASS_NAME,"Pke_EE")
sr.send_keys('sunglasses')

# %%
search_button = driver.find_element(By.CLASS_NAME,"_2iLD__" )
search_button.click()

# %%
B=[]
D=[]
P=[]

# %%
B_tags = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in B_tags:
    BB = i.text
    B.append(BB)
P_tags = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in P_tags:
    PP = i.text
    P.append(PP)
    
D_tags = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in D_tags:
    DD = i.text
    D.append(DD)

# %%
print(len(P),len(B),len(D))
# Out:
# 40 40 38

# %%
min_ = min(len(P), len(B), len(D))
P = P[:min_]
B = B[:min_]
D = D[:min_]
df=pd.DataFrame({'TITLE':B,'RATING':D,"PRICE":P})
df
# Out:
#              TITLE                                             RATING   PRICE
# 0          Eyenaks   UV Protection Rectangular Sunglasses (Free Size)    ₹346
# 1     hayden haiza         UV Protection Retro Square Sunglasses (58)    ₹219
# 2             SRPM             UV Protection Wayfarer Sunglasses (50)    ₹169
# 3          ROADWAY  UV Protection Wayfarer, Sports, Spectacle , Re...    ₹129
# 4          ROADWAY      UV Protection Wayfarer Sunglasses (Free Size)    ₹189
# 5        Elligator             UV Protection Wayfarer Sunglasses (52)    ₹159
# 6        Elligator  UV Protection Wayfarer, Retro Square Sunglasse...    ₹199
# 7        ROYAL SON                   Mirrored Aviator Sunglasses (58)    ₹359
# 8        Elligator   UV Protection, Mirrored Wayfarer Sunglasses (52)    ₹169
# 9        Elligator         UV Protection Retro Square Sunglasses (54)    ₹159
# 10           NuVew  UV Protection Sports, Wrap-around Sunglasses (70)    ₹499
# 11     Eyewearlabs  Polarized, UV Protection Wayfarer Sunglasses (51)  ₹1,236
# 12       Rich Club         UV Protection Retro Square Sunglasses (54)    ₹443
# 13         Zeemork  by Lenskart UV Protection Wayfarer Sunglasses ...    ₹399
# 14   VINCENT CHASE   UV Protection Rectangular Sunglasses (Free Size)    ₹499
# 15        Fastrack  Polarized, UV Protection Rectangular Sunglasse...    ₹539
# 16     Eyewearlabs  Polarized, UV Protection Wayfarer, Retro Squar...  ₹2,199
# 17       ROYAL SON            Mirrored Aviator Sunglasses (Free Size)    ₹594
# 18   Aarna Fashion  Gradient, UV Protection Wayfarer Sunglasses (F...    ₹175
# 19        Fastrack              Gradient Retro Square Sunglasses (60)    ₹549
# 20       ROYAL SON   Polarized, UV Protection Aviator Sunglasses (58)    ₹672
# 21       ROYAL SON      UV Protection Wayfarer Sunglasses (Free Size)    ₹636
# 22        Fastrack             UV Protection Wayfarer Sunglasses (50)    ₹629
# 23       Elligator  by Lenskart Polarized, UV Protection Rectangul...    ₹169
# 24   VINCENT CHASE        UV Protection Shield Sunglasses (Free Size)    ₹749
# 25        Fastrack                UV Protection Round Sunglasses (50)    ₹619
# 26       ROYAL SON  UV Protection, Gradient Retro Square Sunglasse...    ₹404
# 27          AISLIN      UV Protection Wayfarer Sunglasses (Free Size)    ₹418
# 28            doah              UV Protection Aviator Sunglasses (59)    ₹179
# 29        Fastrack   UV Protection Rectangular Sunglasses (Free Size)    ₹569
# 30       ROYAL SON  by Lenskart Polarized, UV Protection Aviator S...    ₹711
# 31  kingsunglasses              UV Protection Aviator Sunglasses (58)    ₹129
# 32   VINCENT CHASE         UV Protection Retro Square Sunglasses (50)    ₹556
# 33        Fastrack            UV Protection Butterfly Sunglasses (60)    ₹799
# 34   Aarna Fashion  UV Protection, Gradient Round, Cat-eye Sunglas...    ₹519
# 35          PIRASO     Polarized, UV Protection Round Sunglasses (47)    ₹388
# 36          AISLIN              UV Protection Aviator Sunglasses (58)    ₹645
# 37     Eyewearlabs              UV Protection Aviator Sunglasses (54)  ₹1,999

# %% [markdown]
# #Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link:
# https://www.flipkart.com/apple-iphone-11-black-64-gb/productreviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market
# place=FLIPKART

# %%
driver = webdriver.Chrome()
driver.get(" https://www.flipkart.com/apple-iphone-11-black-64-gb/productreviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market")

# %%
rat=[]
sm=[]
fl=[]

# %%
R_tags = driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in R_tags:
    RE = i.text
    rat.append(RE)
    
    
sm_tags = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in sm_tags:
    SM = i.text
    sm.append(SM)
    
fl_tags = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
for i in fl_tags:
    FULL = i.text
    fl.append(FULL)

# %%
df=pd.DataFrame({'TITLE':rat,'RATING':sm,"PRICE":fl})
df
# Out:
# Empty DataFrame
# Columns: [TITLE, RATING, PRICE]
# Index: []

# %% [raw]
# The output on site is shown as "Unfortunately the page you are looking for has been moved or deleted"

# %% [markdown]
# #Q6: Scrape data forfirst 100 sneakers you find whenyou visit flipkart.com and search for “sneakers” inthe
# search field.

# %%
driver = webdriver.Chrome()
driver.get("https://www.flipkart.com/")

# %%
sr=driver.find_element(By.CLASS_NAME,"Pke_EE")
sr.send_keys('sneakers')

# %%
search_button = driver.find_element(By.CLASS_NAME,"_2iLD__" )
search_button.click()

# %%
B=[]
D=[]
P=[]

# %%
B_tags = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in B_tags:
    BB = i.text
    B.append(BB)
    
P_tags = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in P_tags:
    PP = i.text
    P.append(PP)
    
D_tags = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in D_tags:
    DD = i.text
    D.append(DD)

# %%
print(len(P),len(B),len(D))
# Out:
# 40 40 36

# %%
min_ = min(len(P), len(B), len(D))
P = P[:min_]
B = B[:min_]
D = D[:min_]
df=pd.DataFrame({'TITLE':B,'RATING':D,"PRICE":P})
df
# Out:
#                     TITLE                                             RATING  \
# 0                  BRUTON    !Combo Pack Of 2 Casual Shoes! Sneakers For Men
# 1                  BRUTON  Combo pack of 2 Trendy Sneaker Shoes Walking S...
# 2               Deals4you                                 Sneakers For Women
# 3                URBANBOX  Trending Stylish Casual Outdoor Sneakers Shoes...
# 4                    ATOM                                   Sneakers For Men
# 5                    PUMA                     Shuffle Ultra Sneakers For Men
# 6                  BRUTON      Combo Pack Of 2 Casual Shoes Sneakers For Men
# 7                  BRUTON  Combo pack of 2 Trendy Men’s Casual Shoes Snea...
# 8                  BRUTON      Modern Trendy Sneakers Shoes Sneakers For Men
# 9         U.S. POLO ASSN.                           CLARKIN Sneakers For Men
# 10                 BRUTON      Combo Pack Of 2 Casual Shoes Sneakers For Men
# 11                 BRUTON  Combo Pack Of 2 Casual Shoes for mens Sneakers...
# 12                 Layasa  Stylish Casual Sports Shoe Sneakers Sneakers F...
# 13  HRX by Hrithik Roshan                      URBAN CHUNKY Sneakers For Men
# 14                   PUMA                           Rungryp Sneakers For Men
# 15               Shoe Lab       Combo Pack Of 2 Casual Shoe Sneakers For Men
# 16           K' Footlance  Synthetic Leather |Lightweight|Comfort|Summer|...
# 17                 BRUTON                                   Sneakers For Men
# 18                   aadi  Stylish Casual Sports Shoe Sneakers Sneakers F...
# 19           UNDER ARMOUR             2 Combo Sneaker Shoes Sneakers For Men
# 20                 Layasa  Lightweight,Comfort,Summer,Trendy,Walking,Outd...
# 21                 BRUTON         SiennaSoftrideBallerina Sneakers For Women
# 22                   aadi  Premium Comfortable LightWeight Walking Casual...
# 23           Robbie jones                                   Sneakers For Men
# 24                   PUMA      Modern Trendy Sneakers Shoes Sneakers For Men
# 25                  BIRDE                                   Sneakers For Men
# 26            kardam&sons                 ST Runner v3 Mesh Sneakers For Men
# 27                 BRUTON                                   Sneakers For Men
# 28               WOODLAND  Casual Sneakers For Boys And Men Sneakers For ...
# 29                   PUMA                          Designer Sneakers For Men
# 30                  AMICO                                   Sneakers For Men
# 31                  AMICO                     Shuffle Ultra Sneakers For Men
# 32               Shoe Lab  Combo pack of 2 Sneakers for Shoes Sneakers Fo...
# 33               HOTSTYLE      Combo Pack Of 2 Casual Shoes Sneakers For Men
# 34                   aadi                           DISRIDE Sneakers For Men
# 35                   PUMA                            CAVE-O Sneakers For Men
#
#      PRICE
# 0     ₹555
# 1     ₹555
# 2     ₹299
# 3     ₹299
# 4   ₹1,088
# 5   ₹1,749
# 6     ₹555
# 7     ₹555
# 8     ₹299
# 9   ₹1,339
# 10    ₹555
# 11    ₹555
# 12    ₹469
# 13    ₹925
# 14  ₹2,149
# 15    ₹399
# 16    ₹335
# 17    ₹555
# 18    ₹299
# 19  ₹2,879
# 20    ₹469
# 21    ₹555
# 22    ₹299
# 23    ₹449
# 24  ₹1,569
# 25    ₹340
# 26    ₹409
# 27    ₹445
# 28  ₹1,639
# 29  ₹3,824
# 30    ₹439
# 31    ₹469
# 32    ₹399
# 33    ₹288
# 34    ₹380
# 35  ₹1,999

# %% [markdown]
# #Q7: Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon. Then
# set CPU Type filter to “Intel Core i7” as shown in the below image:

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome()
driver.get("https://www.amazon.in/")

# %%
sr=driver.find_element(By.CLASS_NAME,"nav-input.nav-progressive-attribute")
sr.send_keys('laptop')

# %%
search_button = driver.find_element(By.CLASS_NAME, "nav-search-submit.nav-sprite")
search_button.click()

# %%
cpu_type = driver.find_element(By.ID, "p_n_feature_thirteen_browse-bin-title")
cpu_type.click()

option = driver.find_element(By.ID, "p_n_feature_thirteen_browse-bin/12598163031")
option.click()

# %%
T = []
R = []
P = []

# %%
laptop_results = driver.find_elements(By.XPATH, "//div[@data-component-type='s-search-result']")[:10]

# %%
T_tags = driver.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-base a-text-normal"]')
for i in T_tags:
    TT = i.text
    T.append(TT)
    
R_tags = driver.find_elements(By.XPATH,'//span[@class="a-size-base puis-bold-weight-text"]')
for i in R_tags:
    RR = i.text
    R.append(RR)

P = []
P_tags = driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in P_tags:
    PP = i.text
    P.append(PP)

# %%
print(len(T))
print(len(R))
print(len(P))
# Out:
# 33
# 0
# 11

# %%
min_ = min(len(T), len(R), len(P))
T = T[:min_]
R = R[:min_]
P = P[:min_]
df=pd.DataFrame({'TITLE':T,'RATING':R,"PRICE":P})
df
# Out:
# Empty DataFrame
# Columns: [TITLE, RATING, PRICE]
# Index: []

# %% [markdown]
# #Q8: Write a python program to scrape data for Top 1000 Quotes of All Time.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome()
driver.get("https://www.azquotes.com/")

# %%
elements = driver.find_elements(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a") 
elements[0].click()

# %%
Q=[]
A=[]
T=[]

# %%
Q_tags = driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in Q_tags:
    QT = i.text
    Q.append(QT)
A_tags = driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in A_tags:
    AT = i.text
    A.append(AT)

T_tags = driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in T_tags:
    TT = i.text
    T.append(TT)

# %%
print(len(Q),len(A),len(T))
# Out:
# 100 100 100

# %%
df=pd.DataFrame({'QUOTE':Q,'AUTHOR':A,"TYPE":T})
df.head(20)
# Out:
#                                                 QUOTE                 AUTHOR  \
# 0   The essence of strategy is choosing what not t...         Michael Porter
# 1   One cannot and must not try to erase the past ...             Golda Meir
# 2   Patriotism means to stand by the country. It d...     Theodore Roosevelt
# 3   Death is something inevitable. When a man has ...         Nelson Mandela
# 4   You have to love a nation that celebrates its ...           Erma Bombeck
# 5   Be more concerned with your character than you...            John Wooden
# 6   Weak people revenge. Strong people forgive. In...        Albert Einstein
# 7   A mind is like a parachute. It doesn't work if...            Frank Zappa
# 8   Never be afraid to raise your voice for honest...       William Faulkner
# 9   There are three kinds of men. The one that lea...            Will Rogers
# 10  A strong nation, like a strong person, can aff...           Jimmy Carter
# 11  The difference between stupidity and genius is...        Albert Einstein
# 12  We the people are the rightful masters of both...        Abraham Lincoln
# 13  With or without religion, you would have good ...        Steven Weinberg
# 14  Human kindness has never weakened the stamina ...  Franklin D. Roosevelt
# 15  A person who never made a mistake never tried ...        Albert Einstein
# 16  My mission in life is not merely to survive, b...           Maya Angelou
# 17  Life is short, Break the Rules. Forgive quickl...             Mark Twain
# 18  This country will not be a good place for any ...     Theodore Roosevelt
# 19  In a world filled with hate, we must still dar...        Michael Jackson
#
#                                         TYPE
# 0   Essence, Deep Thought, Transcendentalism
# 1                  Inspiration, Past, Trying
# 2                        Country, Peace, War
# 3         Inspirational, Motivational, Death
# 4               4th Of July, Food, Patriotic
# 5         Inspirational, Success, Basketball
# 6               Strong, Revenge, Intelligent
# 7          Inspirational, Teacher, Religious
# 8                      Truth, Honesty, Lying
# 9                   Funny, Reading, Learning
# 10            Strong, Thoughtful, Compassion
# 11                         Love, Funny, Life
# 12            Freedom, Men, Democracies Have
# 13                   God, Religious, Atheist
# 14              Respect, Kindness, Character
# 15       Inspirational, Motivational, Change
# 16            Inspirational, Life, Inspiring
# 17                 Love, Inspirational, Life
# 18           Inspiring, Country, 4th Of July
# 19                Inspirational, Dream, Hate

# %% [markdown]
# #Q9: Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead,
# Term of office, Remarks) from https://www.jagranjosh.com/.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome()
driver.get("https://www.jagranjosh.com/")

# %%
elements = driver.find_elements(By.XPATH, "/html/body/div/header/nav/div/div/div[3]/ul/li[3]/a")
elements[0].click()

# %%
pm = driver.find_elements(By.XPATH,"/html/body/div[1]/main/div[1]/div[1]/section/div/ul/li[2]/article/h3/a")

# %%
pm_data = []
table_rows = driver.find_elements(By.XPATH, "//table[@class='table table-striped'][1]//tbody//tr")
for row in table_rows:
    name = row.find_element_by_xpath("./td[1]").text.strip()
    born_dead = row.find_element_by_xpath("./td[2]").text.strip()
    term_of_office = row.find_element_by_xpath("./td[3]").text.strip()
    remarks = row.find_element_by_xpath("./td[4]").text.strip()
    pm_data.append([name, born_dead, term_of_office, remarks])

# %%
print(len(names),len(born_dead),len(TO))
# Out:
# 1 1 1

# %%
max_length = max(len(names), len(born_dead))
names += [np.nan] * (max_length - len(names))
TO += [np.nan] * (max_length-len(TO))
rmk += [np.nan] * (max_length-len(rmk))
born_dead += [np.nan] * (max_length - len(born_dead))
df=pd.DataFrame({'NAME':names,'BORN-DEAD':born_dead,"TERM OF OFC":TO,"rank":rmk})
df
# Out:
#       NAME BORN-DEAD TERM OF OFC     rank
# 0  PM Name   PM Name     PM Name  PM Name

# %% [markdown]
# #Q10: Write a python program to display list of 50 Most expensive cars in the world (i.e.
# Car name and Price) from https://www.motor1.com/

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome()
driver.get('https://www.motor1.com/')
driver.find_elements(By.CLASS_NAME, "m1-search-panel-input.m1-search-form-text")[0].send_keys('50 most expensive cars')

# %%
driver.find_element(By.CLASS_NAME,"features-search_input features-search_input-submit").click()

# %%
driver.find_element(By.CLASS_NAME./features/308149/most-expensive-new-cars-ever/")

# %%
cars=[]
car_tags = driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in car_tags:
    list = i.text
    cars.append(list)

# %%
price=[]
rs_tags = driver.find_elements(By.XPATH,"//strong[contains(text(), 'Price: $')]")
for i in rs_tags:
    list = i.text
    price.append(list)

# %%
print(len(cars),len(price))

# %%
max_length = max(len(cars), len(price))
cars += [np.nan] * (max_length - len(cars))
price += [np.nan] * (max_length - len(price))
df=pd.DataFrame({'cars':cars,'price':price})
df
